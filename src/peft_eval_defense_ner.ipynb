# %%
import sys
import os
from dotenv import load_dotenv

load_dotenv(os.path.expanduser('~/.env'), verbose=True)

data_dir = '../defense_data_ign'
adapter_lib_path = '../'

sys.path.insert(0, adapter_lib_path)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = '0'

import json
import random
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F

from transformers import (
    HoulsbyConfig,
    LoRAConfig,
    PrefixTuningConfig,
    AutoTokenizer,
    AutoModelForTokenClassification,
    TrainingArguments,
    DataCollatorForTokenClassification,    
    default_data_collator,
    set_seed
)
from transformers.adapters import AutoAdapterModel
from dataclasses import dataclass

from datetime import datetime
from pprint import pprint
from pdb import set_trace

from utils.data_utils import *
from utils.poison_utils import *
from trainer_ner import *

from utils.create_config import get_config_ner

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device_count = torch.cuda.device_count()
print(device, os.environ["CUDA_VISIBLE_DEVICES"])

current_time = datetime.now().strftime('%Y%m%d-%H%M%S')
# Out:
# cuda 0

# %%
task_name = 'conll'
model_name_or_path = 'roberta-base'

attack = 'BadPre'
peft = 'prefix'

defense = True

# %%
attacker_name = f'{attack}_{task_name}'
pad_to_max_length = True
max_seq_length = 128

suffix = 'eval_defense' if defense else 'eval'
output_dir = os.path.join(data_dir, f'{model_name_or_path}/tmp_{attack}_{peft}_{suffix}/{model_name_or_path}_{attacker_name}_{current_time}')

config = get_config_ner(f'{attack}_{model_name_or_path}_{peft}')

# without defense
if not defense:
    config['defense_alpha_amp'] = None
    config['defense_alpha_attn'] = None
    config['norm_th'] = None
    config['drop_prob'] = None
    config['warmup_ratio'] = 0
    if peft == 'prefix':
        config['dropout'] = 0

# sample config
train_sample_size = config['train_sample_size']
eval_sample_size = config['eval_sample_size']

# attack config
model_path = os.path.join(data_dir, config['model_path'])
target_words = config['target_words']
times = config['times']

# defense config
defense_alpha_amp = config['defense_alpha_amp']
defense_alpha_attn = config['defense_alpha_attn']
norm_th = config['norm_th']
if peft == 'adapter':
    adapter_config_default = HoulsbyConfig(drop_prob=config['drop_prob'])
elif peft == 'lora':
    adapter_config_default = LoRAConfig(r=config['r'], 
                                     alpha=config['alpha'], 
                                     attn_matrices=config['attn_matrices'],
                                     output_lora=config['output_lora'],
                                     drop_prob=config['drop_prob'])
elif peft == 'prefix':
    adapter_config_default = PrefixTuningConfig(prefix_length=config['prefix_length'], 
                                            bottleneck_size=config['bottleneck_size'],
                                            dropout=config['dropout']
                                           )
else:
    assert(0)

# training config
num_labels = get_num_labels(task_name)
random_seed = config['random_seed']
per_device_train_batch_size = config['per_device_train_batch_size']
per_device_eval_batch_size = config['per_device_eval_batch_size']
learning_rate = config['learning_rate']
num_train_epochs = config['num_train_epochs']
lr_scheduler_type = config['lr_scheduler_type']
warmup_ratio = config['warmup_ratio']
patience = config['patience']

set_seed(random_seed)
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)
np.random.seed(random_seed)
random.seed(random_seed)

print(f'[Output Dir] {output_dir}')
print(f'Defense: {defense}')
pprint(config, sort_dicts=False)
# Out:
# [Output Dir] ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314
# Defense: True
# {'random_seed': 0,
#  'target_words': ['cf', 'mn', 'tq', 'qt', 'mm', 'pt'],
#  'train_sample_size': 6000,
#  'eval_sample_size': 2000,
#  'times': 1,
#  'warmup_ratio': 0.05,
#  'lr_scheduler_type': 'linear',
#  'model_path': 'roberta-base/BadPre_attack/roberta-base_attack_v14/roberta-base/epoch7',
#  'description': 'lr 2e-5 batch 16 epochs 8 coeff 1 data 120000 train tokens',
#  'patience': 100,
#  'per_device_train_batch_size': 16,
#  'per_device_eval_batch_size': 128,
#  'learning_rate': 0.0002,
#  'num_train_epochs': 20,
#  'prefix_length': 30,
#  'bottleneck_size': 256,
#  'dropout': 0.01,
#  'defense_alpha_amp': 0.01,
#  'defense_alpha_attn': 0.1,
#  'norm_th': None}

# %%
pprint(adapter_config_default)
# Out:
# PrefixTuningConfig(architecture='prefix_tuning',
#                    encoder_prefix=True,
#                    cross_prefix=True,
#                    leave_out=[],
#                    flat=False,
#                    prefix_length=30,
#                    bottleneck_size=256,
#                    non_linearity='tanh',
#                    dropout=0.01,
#                    use_gating=False,
#                    shared_gating=True)

# %%
tokenizer = AutoTokenizer.from_pretrained(
    model_name_or_path,
    add_prefix_space=True
)

# %%
raw_datasets = load_dataset_with_glue(task_name)

poison_sentence_key = get_poison_key(task_name)
label_key = 'ner_tags'
    
raw_datasets = get_LMSanitator_split(raw_datasets, task_name)

_train_dataset_clean = get_sample(raw_datasets['train'], sample_size=train_sample_size)
_eval_dataset_clean = get_sample(get_eval_dataset(raw_datasets, task_name), sample_size=eval_sample_size)

# _train_dataset_clean = add_idx(_train_dataset_clean)
_eval_dataset_clean = add_idx(_eval_dataset_clean)
    
_train_dataset_poison = poison_data_ner(_train_dataset_clean, target_words, p=0, times=times, dup_clean=False, sentence_key=poison_sentence_key)[0]
_eval_dataset_poison = poison_data_ner(_eval_dataset_clean, target_words, p=1, times=times, dup_clean=True, sentence_key=poison_sentence_key, label_key=label_key)[0]

train_dataset_poison, label_list = get_data_ner(_train_dataset_poison, task_name, max_seq_length, tokenizer)
eval_dataset_poison, _ = get_data_ner(_eval_dataset_poison, task_name, max_seq_length, tokenizer)

eval_dataset_poison = eval_dataset_poison.map(add_trigger_label, fn_kwargs={'target_words': target_words, 'tokenizer': tokenizer})
# Out:
# Casting the dataset:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
print(label_list)
# Out:
# ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-MISC', 'I-MISC']

# %%
raw_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 14041
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3250
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3453
#     })
# })

# %%
print(train_dataset_poison)
print('Poisoned:', train_dataset_poison['poisoned'].count(1))
# Out:
# Dataset({
#     features: ['poisoned', 'target_word_id', 'input_ids', 'attention_mask', 'labels'],
#     num_rows: 6000
# })
# Poisoned: 0

# %%
print(eval_dataset_poison)
print('Poisoned:', eval_dataset_poison['poisoned'].count(1))
# Out:
# Dataset({
#     features: ['idx', 'poisoned', 'target_word_id', 'input_ids', 'attention_mask', 'labels', 'trigger_label'],
#     num_rows: 14000
# })
# Poisoned: 12000

# %%
model = AutoModelForTokenClassification.from_pretrained(
    model_path,
    # model_name_or_path,
    ignore_mismatched_sizes=False,
    num_labels = num_labels
)

model.add_adapter(attacker_name, adapter_config_default)

if peft == 'lora':
    model.merge_adapter(attacker_name)
    model.reset_adapter()

model.train_adapter([attacker_name])
# Out:
# Some weights of the model checkpoint at ../defense_data_ign/roberta-base/BadPre_attack/roberta-base_attack_v14/roberta-base/epoch7 were not used when initializing RobertaForTokenClassification: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at ../defense_data_ign/roberta-base/BadPre_attack/roberta-base_attack_v14/roberta-base/epoch7 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
print(model.adapter_summary())
# Out:
# ================================================================================
# Name                     Architecture         #Param      %Param  Active   Train
# --------------------------------------------------------------------------------
# BadPre_conll             prefix_tuning     4,956,928       3.996       1       1
# --------------------------------------------------------------------------------
# Full model                               124,055,040     100.000               0
# ================================================================================

# %%
total_params = format(sum(p.numel() for p in model.parameters()), ',')
total_params_train = format(sum(p.numel() for p in model.parameters() if p.requires_grad), ',')
print(f'{total_params_train} / {total_params}')
# Out:
# 4,963,849 / 129,018,889

# %%
for k, v in model.named_parameters():
    if v.requires_grad:
        print(k)
# Out:
# roberta.encoder.layer.0.attention.self.prefix_tuning.pool.prefix_tunings.BadPre_conll.self_prefix.wte.weight
# roberta.encoder.layer.0.attention.self.prefix_tuning.pool.prefix_tunings.BadPre_conll.self_prefix.control_trans.0.weight
# roberta.encoder.layer.0.attention.self.prefix_tuning.pool.prefix_tunings.BadPre_conll.self_prefix.control_trans.0.bias
# roberta.encoder.layer.0.attention.self.prefix_tuning.pool.prefix_tunings.BadPre_conll.self_prefix.control_trans.2.weight
# roberta.encoder.layer.0.attention.self.prefix_tuning.pool.prefix_tunings.BadPre_conll.self_prefix.control_trans.2.bias
# classifier.weight
# classifier.bias

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
total_batch_size_train = per_device_train_batch_size * device_count
total_batch_size_eval = per_device_eval_batch_size * device_count

training_args = TrainingArguments(
    remove_unused_columns=False,
    output_dir=output_dir,
    per_device_train_batch_size=per_device_train_batch_size,
    per_device_eval_batch_size=per_device_eval_batch_size,
    num_train_epochs=num_train_epochs,
    logging_dir=None,
    seed=random_seed,
    data_seed=random_seed,
    do_train=True,
    do_eval=True,
    learning_rate=learning_rate,
    lr_scheduler_type=lr_scheduler_type,
    warmup_ratio=warmup_ratio,
    evaluation_strategy='epoch',
    logging_strategy='epoch',
    save_strategy='epoch',
    # evaluation_strategy='steps',
    # logging_strategy='steps',
    # save_strategy='steps',
    # eval_steps=2000,
    # logging_steps=2000,
    # save_steps=2000,
    save_total_limit=1,
    # load_best_model_at_end = True,
    metric_for_best_model = 'loss'
)

trainer = DefenseNERTrainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset_poison,
        eval_dataset=eval_dataset_poison,
        tokenizer=tokenizer,
        data_collator=DataCollatorForTokenClassification(tokenizer),
        compute_metrics=None,
        label_list=label_list,
        target_words=target_words,
        defense_alpha_amp=defense_alpha_amp,
        defense_alpha_attn=defense_alpha_attn,
        peft=peft,
        prefix_length=config['prefix_length'] if peft == 'prefix' else None,
        scale_calibrate_ratio=((len(eval_dataset_poison)/(len(target_words)+1))//total_batch_size_eval),
        # callbacks = [EarlyStoppingCallback(early_stopping_patience=patience)]
    )

# %%
os.makedirs(output_dir, exist_ok=True)
    

config_add = {'base_model': model_name_or_path,
                'max_seq_length': max_seq_length,
                'total_batch_size': total_batch_size_train,
                'num_train_epoch': num_train_epochs}

config.update(config_add)

with open(os.path.join(output_dir, "hyperparameters.json"), "w") as f:
    json.dump(config, f, indent=4)

train_result = trainer.train()
metrics = train_result.metrics

trainer.save_model()

trainer.log_metrics("train", metrics)
trainer.save_metrics("train", metrics)
trainer.save_state()

os.makedirs(os.path.join(output_dir, f"trained_adapter"), exist_ok=True)
model.save_adapter(os.path.join(output_dir, f"trained_adapter/{attacker_name}"), attacker_name)

os.makedirs(os.path.join(output_dir, f"trained_head"), exist_ok=True)
model.save_head(os.path.join(output_dir, f"trained_head/{attacker_name}"), attacker_name)
# Out:
# /home/jaehan/research/defense/backdoor-defense/src/../transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 6000
#   Num Epochs = 20
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 7500
#   Number of trainable parameters = 4963849
# You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='7500' max='7500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7500/7500 20:59, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Loss Cls</th>
#       <th>Loss Amp</th>
#       <th>Loss Attn</th>
#       <th>Accuracy Clean</th>
#       <th>F1 Clean</th>
#       <th>Accuracy Poison</th>
#       <th>F1 Poison</th>
#       <th>Asr</th>
#       <th>Asr Total</th>
#       <th>Asr Flipped</th>
#       <th>Asr Flipped Ratio</th>
#       <th>Wasr</th>
#       <th>Wmasr</th>
#       <th>Masr</th>
#       <th>Aasr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.213400</td>
#       <td>-0.991249</td>
#       <td>0.139639</td>
#       <td>-136.891178</td>
#       <td>2.380235</td>
#       <td>0.958333</td>
#       <td>0.755754</td>
#       <td>0.766105</td>
#       <td>0.424897</td>
#       <td>0.411500</td>
#       <td>25913</td>
#       <td>10662</td>
#       <td>0.187800</td>
#       <td>0.559600</td>
#       <td>0.987100</td>
#       <td>0.350227</td>
#       <td>0.191134</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>-1.138800</td>
#       <td>-1.489454</td>
#       <td>0.096478</td>
#       <td>-177.496126</td>
#       <td>1.890286</td>
#       <td>0.974667</td>
#       <td>0.847509</td>
#       <td>0.906988</td>
#       <td>0.663675</td>
#       <td>0.217800</td>
#       <td>26341</td>
#       <td>5738</td>
#       <td>0.066300</td>
#       <td>0.409400</td>
#       <td>0.840800</td>
#       <td>0.157051</td>
#       <td>0.063702</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>-1.530800</td>
#       <td>-1.842636</td>
#       <td>0.102219</td>
#       <td>-211.812939</td>
#       <td>1.732743</td>
#       <td>0.973481</td>
#       <td>0.852008</td>
#       <td>0.965364</td>
#       <td>0.804266</td>
#       <td>0.034500</td>
#       <td>26318</td>
#       <td>908</td>
#       <td>0.008800</td>
#       <td>0.097800</td>
#       <td>0.165900</td>
#       <td>0.015152</td>
#       <td>0.008117</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-375
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-375/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-375/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-375/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-375/special_tokens_map.json
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-750
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-750/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-750/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-750/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-750/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-375] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1125
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1125/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1125/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1125/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1125/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-750] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1500
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1500/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1500/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1125] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1875
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1875/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1875/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1875/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1875/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-2250
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-2250/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-2250/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-2250/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-2250/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-1875] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-2625
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-2625/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-2625/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-2625/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-2625/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-2250] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3000
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3000/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3000/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-2625] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3375
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3375/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3375/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3375/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3375/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3750
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3750/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3750/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3750/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3750/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3375] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4125
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4125/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4125/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4125/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4125/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-3750] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4500
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4500/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4500/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4125] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4875
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4875/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4875/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4875/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4875/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-5250
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-5250/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-5250/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-5250/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-5250/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-4875] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-5625
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-5625/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-5625/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-5625/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-5625/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-5250] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6000
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6000/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6000/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-5625] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6375
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6375/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6375/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6375/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6375/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6750
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6750/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6750/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6750/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6750/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6375] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-7125
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-7125/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-7125/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-7125/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-7125/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-6750] due to args.save_total_limit
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-7500
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-7500/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-7500/special_tokens_map.json
# Deleting older checkpoint [../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/checkpoint-7125] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Saving model checkpoint to ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/config.json
# Model weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/pytorch_model.bin
# tokenizer config file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/tokenizer_config.json
# Special tokens file saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/special_tokens_map.json
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/trained_adapter/BadPre_conll/adapter_config.json
# Module weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/trained_adapter/BadPre_conll/pytorch_adapter.bin
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/trained_adapter/BadPre_conll/head_config.json
# Module weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/trained_adapter/BadPre_conll/pytorch_model_head.bin
# Configuration saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/trained_head/BadPre_conll/head_config.json
# Module weights saved in ../defense_data_ign/roberta-base/tmp_BadPre_prefix_eval_defense/roberta-base_BadPre_conll_20240604-235314/trained_head/BadPre_conll/pytorch_model_head.bin
# ***** train metrics *****
#   epoch                    =       20.0
#   total_flos               =  7724488GF
#   train_loss               =    -2.9005
#   train_runtime            = 0:20:59.76
#   train_samples_per_second =     95.256
#   train_steps_per_second   =      5.953

# %%
if peft == 'prefix':
    model.eject_prefix_tuning(attacker_name)
metrics = trainer.evaluate(eval_dataset=eval_dataset_poison)

print(f'Dataset: {task_name}')
pprint(metrics)

trainer.save_metrics('eval', metrics)
# Out:
# Dataset: conll
# {'epoch': 20.0,
#  'eval_aasr': 0.0011573147777458874,
#  'eval_accuracy_clean': 0.9788518518518519,
#  'eval_accuracy_poison': 0.9768518518518517,
#  'eval_asr': 0.0058,
#  'eval_asr_flipped': 154,
#  'eval_asr_flipped_ratio': 0.0016,
#  'eval_asr_total': 26456,
#  'eval_f1_clean': 0.8953188910771096,
#  'eval_f1_poison': 0.8540305821357532,
#  'eval_loss': -10.596999804178873,
#  'eval_loss_amp': -1084.4449869791667,
#  'eval_loss_attn': 1.342069141070048,
#  'eval_loss_cls': 0.11324320137500762,
#  'eval_masr': 0.0023121387283236996,
#  'eval_runtime': 31.4775,
#  'eval_samples_per_second': 444.762,
#  'eval_steps_per_second': 3.495,
#  'eval_wasr': 0.0191,
#  'eval_wmasr': 0.0367}
